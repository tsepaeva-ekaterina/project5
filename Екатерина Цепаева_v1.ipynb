# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Екатерина! Мы уже встречались, но представлюсь повторно.  Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
# Я вижу, что в этом проекте при написании кода активно использовались AI-инструменты. В современной разработке и Data Science это абсолютно допустимо — умение пользоваться нейросетями как ассистентами становится важным навыком. Однако здесь кроется важный нюанс: когда рутинную работу (написание функций, импортов, стандартных слоев нейросети) за тебя делает AI, твоя роль трансформируется из исполнителя в **Архитектора проекта**.
#
# Это означает, что мой фокус как ревьюера смещается. Я не буду подробно останавливаться на синтаксисе или шаблонном коде, если он работает. Вместо этого я буду максимально внимательно и строго анализировать **архитектурную целостность** твоего решения, логические стыковки и обоснованность выбора инструментов.
#
# Твоя задача как Архитектора — не просто собрать пайплайн, который не падает с ошибкой, а гарантировать научную чистоту и эффективность эксперимента. Рекомендую более критично относиться к коду, который предлагает AI, и проверять его на соответствие специфике задачи поиска.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# <p style="font-size: 1.8em; font-weight: bold; margin-top: 20px; margin-bottom: 10px; line-height: 1.2; border-bottom: 1px solid #eee; padding-bottom: 5px;">AI-ассистент в мире кода: как стать пилотом, а не пассажиром</p>
#
# <p> Сегодня невозможно игнорировать тот факт, что AI-ассистенты (такие как ChatGPT, GitHub Copilot и другие) стали частью рабочего процесса.</p>
# <p>Игнорировать их — значит отстать от индустрии. Но использовать их бездумно — значит обесценить собственное обучение и будущие карьерные перспективы. Эта статья — руководство о том, как сделать AI вашим главным союзником в обучении, а не тем, кто учится вместо вас.</p>
#
# <p style="font-size: 1.4em; font-weight: bold; margin-top: 30px; margin-bottom: 10px;">Мнение лидеров индустрии: как гуру AI советуют учиться?</p>
#
# <p style="font-size: 1.1em; font-weight: bold; margin-top: 20px; margin-bottom: 5px;">Эндрю Ын (Andrew Ng): Ускорение, а не замена</p>
# <p>Эндрю Ын, сооснователь Coursera, призывает использовать AI для автоматизации рутины (написание шаблонного кода, форматирование) и для быстрого получения ответов на конкретные вопросы. Это <strong>ускорение, а не замена</strong>. Оно позволяет студенту сфокусироваться на более высокоуровневых задачах — на <strong>архитектуре проекта, интерпретации результатов и постановке гипотез.</strong></p>
# <blockquote>
#     Используйте AI, чтобы спрашивать "Почему?". Не просто просите написать код, а спрашивайте, почему выбрано именно это решение. "Почему для этой задачи лучше подходит <code>RandomForest</code>, а не логистическая регрессия? Объясни плюсы и минусы". AI может стать вашим личным тьютором, доступным 24/7.
# </blockquote>
#
# <p style="font-size: 1.1em; font-weight: bold; margin-top: 20px; margin-bottom: 5px;">Андрей Карпати (Andrej Karpathy): Повышение планки</p>
# <p>Андрей Карпати, легендарный разработчик из OpenAI, считает, что AI не убьет программирование, а <strong>поднимет планку и уровень абстракции</strong>. Раньше нужно было знать ассемблер, потом C, потом Python. Теперь нужно уметь эффективно руководить AI-ассистентом, который пишет на Python. <strong>Ценность смещается от написания кода к проектированию и верификации.</strong></p>
# <blockquote>
#     Относитесь к AI как к неопытному, но очень быстрому напарнику. Он отлично пишет шаблонный, стандартный код, но требует постоянного контроля со стороны "старшего" напарника — то есть вас. Вы должны понимать общую картину, проверять его работу и направлять.
# </blockquote>
#
#
#
# <p style="font-size: 1.4em; font-weight: bold; margin-top: 30px; margin-bottom: 10px;">Глас из окопов: что говорит сообщество разработчиков</p>
# <p>На профессиональных форумах и в блогах (таких как Habr, Reddit) тон более приземленный. Опытные разработчики и тимлиды бьют тревогу, и их опасения полностью совпадают с наблюдениями наставников.</p>
# <ul>
#     <li><strong>Феномен "ChatGPT Junior":</strong> Появилась целая прослойка новичков, которые могут быстро "собрать" проект с помощью AI, но не способны ответить на базовые вопросы по своему же коду, исправить неожиданную ошибку или адаптировать решение под новые требования.</li>
#     <li><strong>Иллюзия компетентности:</strong> AI создает опасное ложное чувство "я это сделал". Студент видит работающий результат, но не проходит через важнейший этап обучения — "продуктивную борьбу" с проблемой, чтение документации и отладку. Именно этот процесс формирует интуицию и настоящее понимание.</li>
# </ul>
#
# <p style="font-size: 1.4em; font-weight: bold; margin-top: 30px; margin-bottom: 10px;">"Красные флаги": как понять, что AI делает работу за вас?</p>
# <p>А теперь практика. Вот несколько верных признаков того, что контроль над проектом перешел от вас к машине.</p>
# <ol>
#     <li><strong>Гигантские ячейки кода.</strong> Работа в Jupyter-ноутбуках — это пошаговое исследование. Загрузили данные -> посмотрели. Очистили -> проверили. Если в вашей ячейке происходит сразу десять действий, вы теряете контроль и возможность анализировать промежуточные результаты.</li>
#     <li><strong>"Заводские" комментарии.</strong> Комментарии в стиле <code>"вставьте сюда ваш путь к файлу"</code> или объясняющие синтаксис (<code># импортируем библиотеку pandas</code>) — это артефакты диалога с AI. Хороший комментарий объясняет <strong>логику</strong> и <strong>причину</strong> вашего решения.</li>
#     <li><strong>Избыточный "Production-ready" код.</strong> Конструкции <code>try-except</code> на каждом шагу, бесконечные проверки на <code>None</code> — это практики из промышленной разработки. В исследовательском проекте они излишни и лишь загромождают код.</li>
#     <li><strong>Код, оторванный от данных.</strong> AI не видит ваши данные и пишет универсальные решения. Если код выглядит так, будто он подошел бы для любого датасета в мире, скорее всего, он написан без погружения в контекст вашей задачи.</li>
#     <li><strong>Классика жанра: <code>if __name__ == "__main__":</code></strong>. Эта конструкция абсолютно бессмысленна в Jupyter-ноутбуке и является стопроцентным маркером скопированного кода.</li>
#     <li><strong>Использование <code>print()</code> для вывода таблиц.</strong> Конструкции вида <code>print(df.head())</code> — еще один характерный маркер. Почему? LLM часто генерирует универсальный код, который будет работать в любом окружении, а <code>print()</code> — это стандартный способ вывода в Python. Однако он выдает неформатированный, "сырой" текстовый результат, который сложно читать. Опытный пользователь Jupyter просто напишет имя переменной (<code>df.head()</code>) в последней строке ячейки, чтобы получить красивую HTML-таблицу. Для вывода в середине ячейки или для нескольких таблиц используется функция <code>display()</code>. Это не просто вопрос эстетики, это вопрос владения своим рабочим инструментом.</li>
# <li><strong>Ячейка как отдельный скрипт.</strong> В разных частях ноутбука вы снова и снова импортируете одни и те же библиотеки (<code>import pandas as pd</code>, <code>import numpy as np</code>) или повторно читаете один и тот же файл с данными. Это происходит, когда вы просите AI решить локальную подзадачу (например, "построй гистограмму для столбца X"). Чтобы сгенерировать гарантированно рабочий код, модель создает самодостаточный блок, который не зависит от выполнения предыдущих ячеек. Она не "помнит", что вы уже импортировали <code>pandas</code> пять ячеек назад. Хорошей практикой считается выносить все импорты в первую ячейку ноутбука, а данные загружать один раз в начале исследования. Это делает код чистым, а логику выполнения — предсказуемой.</li>
#
#  <li><strong>Наукообразные объяснения простых действий.</strong> Вы видите идеально оформленную Markdown-ячейку, которая в стиле научной статьи объясняет, почему нужно разделить данные на выборки перед обучением. Используется сложная терминология ("стратификация для сохранения распределения целевой переменной"), хотя далее следует вызов простой функции <code>train_test_split</code>. Это почерк AI, обученного на документации и статьях. Человек, решающий практическую задачу, объяснит этот шаг гораздо проще.</li>
# </ol>
#
# <p style="font-size: 1.4em; font-weight: bold; margin-top: 30px; margin-bottom: 10px;">Почему слепая вера в AI — это карьерный тупик?</p>
# <ul>
#     <li><strong>Вы не растете.</strong> Пропуская этап самостоятельного решения проблем, вы лишаете себя главного — опыта.</li>
#     <li><strong>Вы не сможете поддерживать свой код.</strong> Когда сгенерированный код сломается (а он сломается), вы не сможете его починить.</li>
#     <li><strong>Вы рискуете допустить скрытые ошибки.</strong> AI может "галлюцинировать" и предлагать решения, которые выглядят убедительно, но приводят к неверным выводам. В аналитике данных цена такой ошибки крайне высока.</li>
#     <li><strong>Вы теряете ценность на рынке.</strong> Чем специалист, который умеет только пересказывать ТЗ для AI, лучше тысяч других? Ваше преимущество — это глубокое понимание, а не скорость копирования.</li>
# </ul>
#
# <p style="font-size: 1.4em; font-weight: bold; margin-top: 30px; margin-bottom: 10px;">От стажера до мастера: практическое руководство по работе с AI</p>
# <p>Итак, как использовать AI, чтобы он усиливал вас, а не заменял?</p>
# <ol>
#     <li><strong>Освойте новый навык — промпт-инжиниринг.</strong> Умение правильно ставить задачи AI — это ключевая компетенция. Будьте конкретны, предоставляйте контекст, примеры, описывайте желаемый формат вывода. Чем лучше ваш запрос, тем качественнее результат.</li>
#     <li><strong>Декомпозиция — ваша зона ответственности.</strong> Вы — архитектор. Разбейте большую задачу на маленькие шаги. AI может помочь с этим, но финальный план и ответственность за него — на вас.</li>
#     <li><strong>Сначала "Как?", потом "Сделай" (подход Эндрю Ына).</strong> Не просите AI сразу написать код. Спросите его о стратегии: "Какие есть способы решить эту задачу? Каковы их плюсы и минусы?". Выберите подход, который вам понятен, и только потом просите помочь с его реализацией.</li>
#     <li><strong>Будьте "старшим программистом" (подход Андрея Карпати).</strong> НИКОГДА не копируйте код вслепую.
#         <ul>
#             <li><strong>Проводите Code Review:</strong> Прочитайте и поймите каждую строчку. Если что-то непонятно, попросите AI объяснить.</li>
#             <li><strong>Выполняйте пошагово:</strong> Вставляйте код в ноутбук маленькими логическими блоками и сразу запускайте. Анализируйте результат на каждом шаге.</li>
#         </ul>
#     </li>
#     <li><strong>Используйте AI как отладчик, а не решатель.</strong> Получили ошибку? Сначала попробуйте исправить ее сами. Если не выходит, скопируйте ошибку и попросите AI объяснить ее причину и предложить варианты для исправления, а не просто выдать готовый код.</li>
#     <li><strong>"Присвойте" себе код.</strong> Удалите все технические комментарии от AI. Отрефакторите код так, чтобы он был идиоматичным для Jupyter-среды (например, замените <code>print(df)</code> на <code>display(df)</code>). Отформатируйте его по стандартам. Теперь это <em>ваш</em> код, за который вы несете полную ответственность.</li>
# </ol>
#
# <p style="font-size: 1.4em; font-weight: bold; margin-top: 30px; margin-bottom: 10px;">Заключение</p>
# <p>В новую эпоху искусственного интеллекта самым ценным навыком становится не способность быстро печатать код, а способность <strong>глубоко мыслить</strong>. Умение ставить задачи, проверять гипотезы, критически оценивать результаты и принимать взвешенные решения — вот что будет отличать настоящего профессионала.</p>
# <p>Используйте AI как рычаг для своего интеллекта, а не как костыль для своих знаний. Будьте пилотом, который управляет мощной машиной, а не пассивным пассажиром. Именно это сделает вас востребованным и сильным специалистом на долгие годы вперед.</p>
#
#
# -----------------------
#
# Я также провел более глубокое исследование проблематики "ChatGPT Junior" (используя Gemini 2.5 Pro в режиме DeepResearch).  Доступно по ссылке
#
# https://docs.google.com/document/d/1CWceW9lEwvdPxdsP4HIYDkrJXwvYfRfMwzjATgKTze8/edit?usp=sharing
#
# </div>

# %% [markdown]
# **Поиск по изображениям**

# %% [markdown]
# **Описание проекта**
#
# Фотохостинг для профессиональных фотографов «Со Смыслом» запускает эксперимент по разработке системы поиска референсных фотографий по текстовому описанию. Пользователи сервиса могут вводить описание нужной им сцены, а система будет находить и показывать наиболее подходящие по смыслу изображения из базы данных.
#
# **Цель проекта**
#
# Разработать прототип (Proof of Concept, PoC) модели машинного обучения, которая определяет степень соответствия между текстовым запросом и изображением. Модель должна принимать на вход векторные представления текста и изображения и выдавать оценку их близости в диапазоне от 0 до 1. На основе этой модели будет собрана демонстрационная версия для презентации руководителю компании.
#
# **Задачи проекта**
#
# - Загрузить и провести предварительный анализ данных (текстовых описаний и изображений).
# - Подготовить данные к обучению: исключить контент, попадающий под юридические ограничения, и провести векторизацию.
# - Провести исследовательский анализ данных (EDA).
# - Обучить несколько регрессионных моделей для предсказания оценки соответствия.
# - Выбрать лучшую модель по заданной метрике качества.
# - Протестировать модель на тестовых данных и продемонстрировать ее работу, включая блокировку "вредного" контента.
# - Оценить практическую осуществимость проекта и сформулировать выводы.
#
# **Исходные данные**
#
# Набор данных для обучения и тестирования включает:
# - train_dataset.csv, CrowdAnnotations.tsv, ExpertAnnotations.tsv: Файлы с текстовыми описаниями и экспертными оценками их соответствия изображениям.
# - train_images/, test_images/: Папки с обучающими и тестовыми изображениями.
# - test_queries.csv: Файл с текстовыми запросами для тестирования готовой модели.
#
# **Этапы проектной работы**
#
# 1. Загрузка данных и исследовательский анализ:
# - Импорт необходимых библиотек
# - Загрузка и объединение данных из CSV и TSV-файлов
# - Анализ распределения экспертных оценок
# - Исследование взаимосвязи между краудсорсинговыми и экспертными оценками
# 2. Подготовка данных к обучению:
# - Составление списка ключевых слов, связанных с нежелательным контентом
# - Фильтрация обучающего датасета на основе составленного списка для исключения потенциально проблемных пар «текст-изображение»
# - Векторизация текстовых описаний с использованием предобученной модели
# - Векторизация изображений с использованием предобученной сверточной сети
# - Анализ и описание результирующих векторов
# 3. Обучение модели:
# - Формирование общего датасета: конкатенация векторов текста и изображения в один признаковый вектор, целевой переменной является экспертная оценка
# - Разделение данных на обучающую и валидационную выборки
# 4. Обучение и сравнение нескольких моделей:
# - Линейная регрессия
# - Полносвязная нейронная сеть, подбор гиперпараметров для нейросетевой модели
# - Выбор оптимальной модели на основе метрики MSE или MAE
# 5. Тестирование модели и демонстрация ее работы:
# - Написание функции поиска, которая для заданного текстового запроса проверяет его на наличие запрещенной лексики и в случае обнаружения возвращает дисклеймер; векторизует текст, вычисляет близость с векторами всех тестовых изображений; возвращает имя файла изображения с наивысшей предсказанной оценкой.
# - Качественная проверка работы модели
# - Анализ ошибок модели: на каких запросах она работает хорошо, а на каких ошибается
# 6. Общий вывод по работе:
# - Описание лучшей модели и достигнутого качества
# - Оценка практической осуществимости проекта
# - Формулирование рекомендаций по дальнейшему развитию системы

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 Да, это хорошая практика - дать описание контекста и проблемы, которую мы решаем. </div>

# %% [markdown]
# **Загрузка и исследовательский анализ данных**

# %%
# Импорт библиотек и настроек
# Базовые библиотеки
import os
import re
import random
from pathlib import Path
import numpy as np
import pandas as pd

# Визуализация
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

# Sklearn
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from sklearn.preprocessing import Normalizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    r2_score,
    root_mean_squared_error
)

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input
from tensorflow.keras.regularizers import l2

# PCA
from sklearn.decomposition import PCA

# Настройки воспроизводимости
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

# Настройки matplotlib
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['axes.grid'] = True

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %%
# Загрузка данных
DATA_DIR = r"C:\Users\Admin\Desktop\dsplus_integrated_project_4\to_upload"
TRAIN_IMG_DIR = os.path.join(DATA_DIR, 'train_images')
TEST_IMG_DIR = os.path.join(DATA_DIR, 'test_images')

# Загрузка всех файлов данных
train_df = pd.read_csv(os.path.join(DATA_DIR, 'train_dataset.csv'))
print('train_df:')
display(train_df.head())

expert_df = pd.read_csv(os.path.join(DATA_DIR, 'ExpertAnnotations.tsv'), sep='	', header=None, names=['image', 'query_id', 'expert1', 'expert2', 'expert3'])
print('\nexpert_df:')
display(expert_df.head())

crowd_df = pd.read_csv(os.path.join(DATA_DIR, 'CrowdAnnotations.tsv'), sep='	', header=None, names=['image', 'query_id', 'score'])
print('\ncrowd_df:')
display(crowd_df.head())

test_queries_df = pd.read_csv(os.path.join(DATA_DIR, 'test_queries.csv'), sep='|')
print('\ntest_queries_df:')
display(test_queries_df.head())

test_images_df = pd.read_csv(os.path.join(DATA_DIR, 'test_images.csv'), sep='|')
print('\ntest_images_df:')
display(test_images_df.head())
# Out:
# train_df:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text
# 0  A young child is wearing blue goggles and sitt...
# 1  A young child is wearing blue goggles and sitt...
# 2  A young child is wearing blue goggles and sitt...
# 3  A young child is wearing blue goggles and sitt...
# 4  A young child is wearing blue goggles and sitt...
# expert_df:
#                        image                     query_id  expert1  expert2  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2        1        1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2        1        1
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Екатерина, в коде часто встречается `print(df.head())`. Давай это исправим.
#
# **В чем тут хитрость с AI-ассистентами?**
# Нейросети обучались на огромном количестве обычных Python-файлов (скриптов). В таких файлах `print()` — это единственный способ увидеть данные на экране. Поэтому нейронка «по привычке» выдает тебе такой код. Но то, что хорошо для консоли, в Jupyter-ноутбуке выглядит не очень: таблица превращается в обычный текст, который неудобно читать.
#
# **Как лучше сделать?**
# Jupyter умеет рисовать красивые интерактивные таблицы с подсветкой и нормальными отступами. Чтобы их увидеть, достаточно:
#
# * Просто написать имя переменной в самой последней строчке ячейки (например, `train_df.head()`).
# * Или использовать функцию `display(train_df.head())`.
#
# Обычно этот комментарий желтый, но учитыая что это один из заключительных проектов, а особенность работы в Jupyter ноутбуке обсуждалась в самых первых проектах, то прошу тебя внести эти корректировки.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Привет! Убрала print, использовала display. (и не привыкла еще работать локально)
#
# </div>

# %%
# Анализ данных
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# А вот оборачивать результат работы метода  `.info()` в функцию `print()` или `display()` это лишнее. Метод  `info()` и сам напечатает тебе нужную информацию. А вот через `print()`/`display()` ты выводишь только то,что данный метод возвращает - т.е. `None`
#
# --------------
#
# Почему AI-ассистенты любят оборачивать  `df.info()` в print? Это тоже "статистическое смещение". Они привыкли, что если нужно что-то вывести, то нужно воспользоваться print.  И могут просто не обращать внимание, что info() возвращает None.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Не знала сама (или забыла)
#
# </div>

# %%
# Подробный анализ данных (EDA)

# Анализ структуры каждого файла
print("Анализ TRAIN_DATASET")
print(f"Размер: {train_df.shape}")
print(f"\nИнформация о колонках:")
display(train_df.info())
print(f"\nСтатистика:")
display(train_df.describe())
print(f"\nПропуски: {train_df.isna().sum().sum()}")

print("Анализ EXPERT ANNOTATIONS")
print(f"Размер: {expert_df.shape}")
print(f"\nИнформация о колонках:")
display(expert_df.info())
print(f"\nСтатистика оценок экспертов:")
display(expert_df[['expert1', 'expert2', 'expert3']].describe())

print("Анализ CROWD ANNOTATIONS")
print(f"Размер: {crowd_df.shape}")
print(f"\nИнформация о колонках:")
display(crowd_df.info())
print(f"\nСтатистика оценок краудсорсеров:")
display(crowd_df['score'].describe())
# Out:
# Анализ TRAIN_DATASET
# Размер: (5822, 3)
#
# Информация о колонках:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
# None
# Статистика:
#                             image                     query_id  \
# count                        5822                         5822
# unique                       1000                          977
# top     3364151356_eecd07a23e.jpg  2600867924_cd502fc911.jpg#2
# freq                           10                           34
#
#                                                query_text
# count                                                5822
# unique                                                977
# ...

# %%
# Проверка пропусков и дубликатов
def initial_check(df, name):
    print(f"\n{name}")
    display(df.info())
    print("\nПропуски:")
    display(df.isna().sum())
    print("\nДубликаты:", df.duplicated().sum())

initial_check(train_df, "train_dataset")
initial_check(crowd_df, "crowd_annotations")
initial_check(expert_df, "expert_annotations")
initial_check(test_queries_df, "test_queries")
# Out:
# train_dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
# None
# Пропуски:
# image         0
# query_id      0
# query_text    0
# dtype: int64
# Дубликаты: 0
#
# crowd_annotations
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 47830 entries, ('1056338697_4f7d7ce270.jpg', '1056338697_4f7d7ce270.jpg#2') to ('997722733_0cb5439472.jpg', '997722733_0cb5439472.jpg#2')
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     47830 non-null  float64
#  1   query_id  47830 non-null  int64
#  2   score     47830 non-null  int64
# dtypes: float64(1), int64(2)
# memory usage: 1.4+ MB
# None
# ...

# %% [markdown]
# Установлены и импортированы все необходимые библиотеки для работы с данными, машинного обучения и глубокого обучения.
# Данные загружены корректно, но для работы необходимо объединить таблицы train_df и expert_df по ключам image и query_id. Это даст полный набор данных с текстовыми запросами и соответствующими экспертными оценками.
# Важно отметить, что в данных присутствует контент, связанный с детьми, это подтверждает необходимость этапа фильтрации для исключения потенциально нежелательного контента.
#
# Обучающий датасет (train_df) содержит 5822 пары "изображение-текст".
# Экспертные оценки (expert_df) также содержат 5822 записи, по 3 оценки от каждого эксперта на пару.
# Краудсорсинговые оценки (crowd_df) значительно больше — 47830 записей, что указывает на более массовую, но менее согласованную разметку.
#
# Экспертные оценки показывают высокую согласованность. Среднее стандартное отклонение между тремя экспертами составляет всего ~0.25, что указывает на хорошее согласие. Большинство оценок сосредоточено вокруг значений 1 и 2 (шкала от 1 до 4).
# Краудсорсинговые оценки имеют другое распределение (шкала от 0 до 6) и сильно смещены в сторону максимального значения 3 (медиана и 75-й перцентиль равны 3). Это говорит о возможной систематической ошибке или упрощенном подходе к оценке со стороны краудсорсеров.
# Критическая проблема: Не удалось найти ни одной пересекающейся пары (image, query_id) между экспертными и краудсорсинговыми данными для прямого сравнения (correlation = nan). Это означает, что два набора размечали разные subsets данных, и использовать краудсорсинговые оценки для обучения модели будет некорректно. Фокус необходимо сместить на экспертные данные.
#
# Пропуски в данных отсутствуют.
# Обнаружено 47 830 дубликатов в краудсорсинговых данных. Это требует дополнительного исследования (возможно, дублирование строк или особенности MultiIndex), но так как мы фокусируемся на экспертных данных, эта проблема становится менее критичной.
# В тестовом наборе (test_queries_df) содержится 500 текстовых запросов, для которых нужно будет найти релевантные изображения из test_images_df.

# %%
# Анализ качества разметки (сравнение экспертов и краудсорсеров)
print("Анализ качества разметки")

expert_df_temp = expert_df.copy()
expert_df_temp['expert_mean'] = expert_df_temp[['expert1', 'expert2', 'expert3']].mean(axis=1)

expert_df_temp['image'] = expert_df_temp['image'].astype(str)
crowd_df['image'] = crowd_df['image'].astype(str)

expert_df_temp['query_id'] = expert_df_temp['query_id'].astype(str)
crowd_df['query_id'] = crowd_df['query_id'].astype(str)

quality_comparison = expert_df_temp.merge(
    crowd_df,
    on=['image', 'query_id'],
    how='inner'
)

print(f"\nПар для сравнения: {len(quality_comparison)}")
print(f"\nКорреляция между средней оценкой экспертов и краудсорсеров:")
correlation = quality_comparison['expert_mean'].corr(quality_comparison['score'])
print(f"Pearson correlation: {correlation:.4f}")

# Согласованность между экспертами
expert_df_temp['expert_std'] = expert_df_temp[['expert1', 'expert2', 'expert3']].std(axis=1)
print(f"\nСогласованность между экспертами (среднее STD): {expert_df_temp['expert_std'].mean():.4f}")
print(f"Минимальное STD: {expert_df_temp['expert_std'].min():.4f}")
print(f"Максимальное STD: {expert_df_temp['expert_std'].max():.4f}")

# Визуализация распределения оценок
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Распределение оценок каждого эксперта
for i, expert in enumerate(['expert1', 'expert2', 'expert3']):
    axes[0, i].hist(expert_df[expert], bins=4, edgecolor='black', alpha=0.7)
    axes[0, i].set_title(f'Распределение оценок {expert}')
    axes[0, i].set_xlabel('Оценка')
    axes[0, i].set_ylabel('Частота')
    axes[0, i].grid(True, alpha=0.3)

# Средняя оценка экспертов
axes[1, 0].hist(expert_df_temp['expert_mean'], bins=30, edgecolor='black', alpha=0.7, color='green')
axes[1, 0].set_title('Распределение средней оценки экспертов')
axes[1, 0].set_xlabel('Средняя оценка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True, alpha=0.3)

# Оценки краудсорсеров
axes[1, 1].hist(crowd_df['score'], bins=30, edgecolor='black', alpha=0.7, color='orange')
axes[1, 1].set_title('Распределение оценок краудсорсеров')
axes[1, 1].set_xlabel('Оценка')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].grid(True, alpha=0.3)

# Сравнение экспертов и краудсорсеров
if len(quality_comparison) > 0:
    axes[1, 2].scatter(quality_comparison['expert_mean'], quality_comparison['score'], alpha=0.3)
    axes[1, 2].plot([1, 4], [1, 4], 'r--', label='Идеальное совпадение')
    axes[1, 2].set_title('Эксперты vs Краудсорсеры')
    axes[1, 2].set_xlabel('Средняя оценка экспертов')
    axes[1, 2].set_ylabel('Оценка краудсорсеров')
    axes[1, 2].legend()
    axes[1, 2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Анализ качества разметки
#
# Пар для сравнения: 0
#
# Корреляция между средней оценкой экспертов и краудсорсеров:
# Pearson correlation: nan
#
# Согласованность между экспертами (среднее STD): 0.2538
# Минимальное STD: 0.0000
# Максимальное STD: 1.7321

# %% [markdown]
# Распределение индивидуальных экспертных оценок: На трех гистограммах показано, как каждый из трех экспертов (expert1, expert2, expert3) выставлял оценки релевантности пар "изображение-текст". По оси X отложена оценка (по 4-балльной шкале: 1, 2, 3, 4), по оси Y — количество таких оценок.
# Наблюдение: Все три эксперта демонстрируют сходное поведение. Наиболее часто они ставят оценку 1 (наивысшая релевантность), следующей по частоте является оценка 2. Оценки 3 и 4 встречаются значительно реже. Это указывает на то, что в датасете преобладают пары, которые эксперты сочли очень релевантными.
#
# Распределение средних экспертных оценок: Гистограмма показывает распределение усредненных по трем экспертам оценок для каждой пары. Поскольку индивидуальные оценки дискретны (целые числа от 1 до 4), их среднее значение принимает дробные значения в интервале от 1.0 до 4.0. Распределение имеет явный пик в районе значения 1.0 и длинный хвост в сторону более высоких (худших) оценок. Это подтверждает вывод о том, что большинство пар были единодушно признаны экспертами высокорелевантными. Плавная форма графика по сравнению с дискретными гистограммами сверху является следствием усреднения.
#
# Распределение краудсорсинговых оценок: Гистограмма показывает распределение оценок, данных краудсорсерами. Важно отметить, что шкала оценок здесь иная — от 0 до 6. Распределение кардинально отличается от экспертного. Оно резко скошено и имеет огромный пик на оценке 3.0. Более 75% всех оценок краудсорсеров имеют это значение. Оценки 0, 1, 2, 4, 5 и 6 встречаются крайне редко. Это говорит о том, что краудсорсеры либо не были мотивированы вдумчиво оценивать пары, что привело к выбору "стандартного" ответа по умолчанию. Качество таких данных является крайне низким.
#
# Сравнение экспертных и краудсорсинговых оценок: Это пустой график. На нем планировалось отобразить точечную диаграмму рассеяния, где по оси X — средняя экспертная оценка пары, а по оси Y — краудсорсинговая оценка для той же самой пары. В данных не найдено ни одной общей пары (image, query_id), которая была бы оценена и экспертами, и краудсорсерами. Это критически важное наблюдение, которое означает, что эти два набора данных несопоставимы. Нельзя использовать краудсорсинговые данные для валидации или обучения модели, построенной на экспертных данных, и наоборот.
#
# Визуальный анализ окончательно убеждает в том, что экспертные данные являются единственным надежным источником целевой переменной. Распределение их оценок выглядит осмысленным и вариативным. Краудсорсинговые данные имеют аномальное распределение и не пересекаются с экспертными.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Екатерина, на самом старте проекта мы столкнулись с критической проблемой: практически полностью отсутствует этап **EDA (исследовательского анализа данных)**. Из 5 доступных файлов с данными загружены и использованы только 2.
#
#
# **Почему это важно исправить?**
#
# 1. **Потеря данных:** Игнорируя `CrowdAnnotations.tsv`  ты выбрасываешь десятки тысяч полезных примеров. В реальности мы боремся за каждую строчку данных, а не избавляемся от них без веской причины. Да, в этом проекте я допускаю стратегию "использовать только экспертные оценки", но это должен быть осознанный выбор, а не потому что "так получилось".
# 2. **Слепое обучение:** Без EDA ты не видишь, насколько «шумная» разметка в краудсорсинге и насколько она стабильна у экспертов. Нужно обязательно сравнить их на «родных» парах (используя формат `query_id`, где зашифровано имя файла).
# 3. **Понимание задачи:** Как говорит известный инженер AI Андре Карпаты (Andrej Karpathy):
#
# > «Первый шаг к обучению нейронной сети — вообще не трогать код нейросети, а вместо этого начать с тщательного изучения ваших данных... нужно стать "одним целым с данными" (become one with the data)».
# > *Источник: [A Recipe for Training Neural Networks*](https://karpathy.github.io/2019/04/25/recipe/)
#
# Андре подчеркивает, что нужно часами просматривать тысячи примеров, изучать их распределения и аномалии. Только тогда ты поймешь, какие признаки на самом деле важны.
#
# **Что нужно сделать:**
#
# * Загрузить **все** таблицы: `train_dataset.csv`, `CrowdAnnotations.tsv`, `ExpertAnnotations.tsv`, тестовые данные. Провести их первичный осмотр, включая пропуски, дубликаты.
# * Провести полноценный EDA: изучить распределение оценок, длину текстов, посмотреть на сами картинки.
# * Проанализировать качество разметки. Сравни оценки экспертов и краудсорсеров для одних и тех же пар.
# * Обосновать выбор стратегии использования оценок, свои мысли по этому поводу оставлю ниже).
# * Исследовать достпные картинки (посмотреть на них глазами, понять все ли картинки, упомянутые в данных имеются в наличии).
#
# Без этого этапа мы не можем доверять результатам модели, так как не понимаем, на чем именно она учится.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Теперь задействованы все файлы из задания
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
#
# В этом проекте есть несколько возможных стратегий работы с обучающими и краудсорс оценками,  вот эти стратегии с плюсами и минусами:
#
#
#    - использовать соединение через outer, в этом случае, при корректной обработке пропусков мы можем получить более 50К размеченых пар. К плюсам данного подхода можно отнести большое количество данных. Минус - в основном это будут данные, размеченные краудсорсерами, а там качество раметки ниже.
#    - использовать только экспертные оценки. плюс - высокое качество данных (разметка имеет шкалу). Минус - данных меньше.  Поясню по поводу качества разметки на примере: если на изображении одна собака, а в описании "две собаки бегут по берегу", то эксперты поставять соответствие 0,6-0,7 (переводя в шкалу 0-1), а краудсорсеры поставят 0.  Но на экспертных оценках модель хотя-бы научится находить собак, а на краудсор оценках ничему не начится.
#
#    - использование соединения через left.  Данный подход очевидно проигрывает второму варианту: данных столько же, нужно дополнительно возиться с объединением, но качество разметки снижается.. Но это соответсвует предложениям авторов проекта, поэтому такой подход имеет право на жизнь
#
#    - объединение через inner. Тут все плохо - и данных ОЧЕНЬ мало (в два раза меньше, чем использовать только экспертные оценки) и качество у них "подпорчено". И навыков по обработке пропусков не получаем.....
#
#
# </div>

# %%
# Агрегация экспертных оценок
expert_df['score'] = expert_df[['expert1', 'expert2', 'expert3']].mean(axis=1)

# Нормализация в диапазон [0, 1]
expert_df['score'] = (expert_df['score'] - 1) / 3

# Объединение с train_dataset
train_df = train_df.merge(
    expert_df[['image', 'query_id', 'score']],
    on=['image', 'query_id'],
    how='inner',
    suffixes=('_old', '')
)

# Удаление score_old, если есть
if 'score_old' in train_df.columns:
    train_df = train_df.drop(columns=['score_old'])

train_df = train_df.drop_duplicates().reset_index(drop=True)

print(f"Размер данных после merge: {train_df.shape}")
print(f"\nПроверка диапазона score:")
print(f"Минимум: {train_df['score'].min():.4f}")
print(f"Максимум: {train_df['score'].max():.4f}")
print(f"Среднее: {train_df['score'].mean():.4f}")

# Проверка пропусков
print("\nПропуски:\n", train_df.isna().sum())

# Проверка дубликатов
print("\nДубликаты:", train_df.duplicated().sum())
# Out:
# Размер данных после merge: (5822, 4)
#
# Проверка диапазона score:
# Минимум: 0.0000
# Максимум: 1.0000
# Среднее: 0.2159
#
# Пропуски:
#  image         0
# query_id      0
# query_text    0
# score         0
# dtype: int64
#
# Дубликаты: 0

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Екатерина, я заметил ошибку в расчете целевой переменной: `expert_df['score'] = expert_df['score'] / 4`.
#
# **В чем проблема:**
# Оценки экспертов в наших данных зафиксированы по шкале от 1 до 4. Если мы просто делим на 4, то получаем диапазон [0.25, 1].
# Это критическая логическая ошибка для модели по двум причинам:
#
# 1. Твоя модель физически никогда не сможет предсказать «ноль» (полное несоответствие), потому что в её обучающих данных минимальная оценка — 0.25.
# 2. Это искажает смысл метрик.
#
# **Как исправить:**
# Чтобы корректно перевести шкалу [1, 4] в диапазон [0, 1], нужно использовать линейное преобразование:
# `target = (оценка - 1) / 3`.
# Тогда 1 превратится в 0, а 4 — в 1. Это стандартная практика в таких задачах.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Визу использование  `train_df.rename(columns={'score_y': 'score'}, inplace=True)` и последующаю очистку дубликатов колонок.
#
# **В чем здесь проблема:**
# При чистом, последовательном запуске ноутбука (от первой ячейки до последней) колонке `score_y` взяться неоткуда. Она появляется в только как побочный эффект при многократном выполнении операции `merge` в одной и той же ячейке без сброса данных, либо при конфликте имен, который здесь не должен возникать.
#
# Похоже, что в процессе работы возникла путаница с колонками из-за перезапуска ячеек, и начала это исправлять, не разобравшись в причинах. Поэтмоу и появился «защитный код», который сейчас просто удаляет колонку, которая может появиться, если ячейку запустят несколько раз. Но в итоговом проекте такой код выглядит как «костыль» для проблемы, которой в норме не существует.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Исправила диапазон и объединение
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Вижу конструкцию `train_df.head()` в середине ячейки. Подумай, что она делает? Нужна ли она? В качестве подсказки можешь посмотреть комментарий ниже
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>минутка теории</b>
#  По умолчанию jupyter notebook выводит результат вычислений в последней строке ячейки, если этот результат не записан в переменную. Мы часто пользуемся этим, обратившись к какому-нибудь объекту в последней строке и видим результат без дополнительных print() или dispay()
#
#
#   Ниже три ячейки с кодом. Обрати внимание, если просто сделать вычисление - то результат выводится, но если добавить точку с запятой или записать результат в переменную, то ничего не происходит. Обрати внимание, когда происходит вывод:
#    - последня строка
#    - нет точки с запятой в конце
#
#    - результат не записан в переменную
#
# И досточно убрать одно из этих условий, как вывода нет.
#
# ![image-4.png](attachment:image-4.png)
#
#  Функции matlitlib не только выводят графики, но и возвращают python объекты axis. Это внутренняя кухня, чтобы можно было строить сложные графики. Но для нас побочным эффектом является то, что в ноутбуке мы видим текстовое предоставление объекта, которое выводит ноутбук. И для красоты такое поведение стоит заблокировать.
#
#
#
# </div>

# %% [markdown]
#  В результате операции merge получен датасет размером 5822 строки и 4 колонки. Все строки исходного train_df были успешно сопоставлены с экспертными оценками (использовался how='inner'), что подтверждает их полную совместимость по ключам image и query_id.
# Значения score нормализованы в интервал [0, 1], где 0 — наивысшая релевантность, 1 — наименьшая. Минимальное и максимальное значения (0.0 и 1.0) точно соответствуют границам ожидаемого диапазона.
# Среднее значение ~0.22 значительно смещено в сторону нуля. Это визуально подтверждает вывод из предыдущего анализа: подавляющее большинство пар "изображение-текст" эксперты оценили как высокорелевантные.
# В колонке score и других колонках отсутствуют пропуски. Данные чистые и готовы к использованию.
# В DataFrame отсутствуют дублирующиеся строки. Данные имеют хорошее качество и не требуют дополнительной очистки от повторов.
#
# Тренировочный датасет успешно подготовлен. Он содержит текстовые запросы, соответствующие изображения и надежную, согласованную целевую переменную (score), полученную путем агрегации мнений нескольких экспертов. Это создает прочную основу для обучения и валидации модели.

# %%
# Анализ распределения таргета
plt.hist(train_df['score'], bins=30)
plt.title('Распределение экспертных оценок')
plt.xlabel('score')
plt.ylabel('count')
plt.show()

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %%
# Проверка существования файлов изображений
#existing_images = set(os.listdir(TRAIN_IMG_DIR))
#train_df = train_df[train_df['image'].isin(existing_images)]
#train_df = train_df.reset_index(drop=True)

# Нормализация имен
#train_df['image'] = train_df['image'].str.strip().str.lower()

# Список файлов, также с нижним регистром для сравнения
#existing_images = set([img.lower() for img in os.listdir(TRAIN_IMG_DIR)])

# Фильтрация  DataFrame
#train_df = train_df[train_df['image'].isin(existing_images)]
#train_df = train_df.reset_index(drop=True)
#train_df = train_df[train_df['image'].isin(existing_images)]

#print(f"Всего файлов в директории: {len(existing_images)}")

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Екатерина, блок с проверкой наличия файлов — это яркий пример **«защитного программирования»**.
#
# В другой ситуации я бы, возможно, похвалил за такую предусмотрительность, но здесь эта «защита» выглядит избыточной. Когда мы видим в коде трехкратную фильтрацию и повторную нормализацию имен, это скорее сигнализирует о том, что этап глубокого знакомства с данными (EDA) был пропущен.
#
# **Почему так произошло?**
# AI-ассистенты часто пишут код «вслепую». Не имея возможности просто заглянуть в папку и посмотреть на названия файлов, они предлагают универсальные и многослойные механизмы защиты, чтобы код гарантированно не упал с ошибкой `FileNotFoundError`. Но для дата-сайентиста важно **знать** свои данные, а не просто защищаться от них.
#
# **Как сделать лучше?**
# Вместо того чтобы строить сложные фильтры, достаточно было один раз провести EDA: посмотреть на список файлов, убедиться в их количестве и регистре имен. Тогда весь этот блок превратился бы в одну-две понятные строки. Твоя задача как специалиста — доверять результатам своего анализа, а не плодить избыточные проверки «на всякий случай».
#
# Это не ошибка, но хороший повод задуматься о том, насколько ты контролируешь процесс, а насколько полагаешься на автоматические «костыли» ассистента.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Поняла
#
# </div>

# %% [markdown]
# Гистограмма показывает, как часто встречаются те или иные значения оценки (score) в наборе данных. Распределение оценок неравномерное (не сбалансированное). Много оценок 1, 1.5, 2, меньшее количество 3 и 4.
# Это типичная проблема регрессии с смещенным распределением. Если обучать модель на таких данных, она может научиться хорошо предсказывать только наиболее частые оценки и очень плохо — редкие. Нужно будет или использовать методы взвешивания объектов или функции потерь, чувствительные к дисбалансу, или применить стратегию стратифицированной выборки при разбиении на train/validation, чтобы гарантировать, что в каждом сете будут представлены все диапазоны оценок.
#
# Проверка существования файлов изображений выполнена. В папке с изображениями TRAIN_IMG_DIR физически находится только 1000 файлов. Это означает, что в исходном CSV-файле были перечислены имена файлов, которых нет в папке. Был отфильтрован DataFrame, оставив в нем только те строки, для которых изображения действительно существуют. После фильтрации и сброса индекса размер train_df стал равен 1000 строк. Теперь каждой строке с данными (оценкой) соответствует реальный файл изображения.

# %% [markdown]
# **Подготовка данных к обучению модели**

# %%
# Юридические ограничения
BAD_WORDS = [
    'child', 'children', 'kid', 'kids', 'baby', 'babies',
    'boy', 'boys', 'girl', 'girls', 'teen', 'teenager',
    'toddler', 'infant'
]

bad_queries = train_df[
    train_df['query_text']
    .str.lower()
    .str.contains('|'.join(BAD_WORDS), regex=True)
].copy()

expert_df['expert_mean'] = expert_df[['expert1', 'expert2', 'expert3']].mean(axis=1)

bad_queries = bad_queries.merge(
    expert_df[['image', 'query_id', 'expert_mean']],
    on=['image', 'query_id'],
    how='inner'
)

BAD_THRESHOLD = 3.0

bad_images = bad_queries[
    bad_queries['expert_mean'] >= BAD_THRESHOLD
]['image'].unique()

train_df = train_df[
    ~train_df['image'].isin(bad_images)
].reset_index(drop=True)

print(f"Удалено изображений: {len(bad_images)}")
print(f"Размер датасета после очистки: {len(train_df)}")
# Out:
# Удалено изображений: 82
# Размер датасета после очистки: 5359

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Ты удаляешь комментарии, в которых есть слова, обозначающие детей. Но наша задача убрать изображения, содержащие детей. Есть два способа сделать это:
#
#  - Определить список плохих изображений, как изображения удовлетворяющие условиям:
#     - Комментарий содержит плохие слова
#     - <b>Оценка соответствия комментария и изображения выше порога.</b>
#  - Удалить из нашего датасета все пары "изображение/описание" с плохими изображениями.
#
#
# И второй, очень красивый способ. Он основан на том, что `query_id` содержит в с себе имя изображения, для которого он был написан (такая пасхалочка от авторов датасета).
#
#  - Определить список плохих комментариев
#  - У `query_id`  плохих комментариев отрезать два последних символа и получим список плохих изображений.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Переделала фильтрацию, теперь исключаются изображения
#
# </div>

# %% [markdown]
# Фильтрация проводилась по двум параметрам:
# - Наличие "плохих" слов в запросе: С помощью регулярного выражения ищутся запросы, содержащие слова из списка BAD_WORDS (например, 'child', 'boy', 'girl').
# - Низкая релевантность изображения к запросу: Низкая релевантность (оценка близкая к 4) означает, что изображение не соответствует текстовому запросу. Поэтому если для потенциально опасного запроса (query_text) эксперты поставили низкую оценку релевантности (в данном случае expert_mean >= 3.0), это с высокой вероятностью означает, что на изображении показано не то, что описано в запросе. Такие изображения считаются потенциально рискованными и подлежат удалению.
#
# Из датасета было удалено 82 изображения, которые были помечены как потенциально проблемные по юридическим соображениям. Вместе с этими изображениями из датасета удалились и все связанные с ними текстовые запросы. Размер тренировочного датасета сократился с 5822 до 5359 строк. Это означает, что для обучения модели остался только безопасный и релевантный контент.

# %%
# Векторизация изображений (ResNet50)
cnn_model = ResNet50(
    weights='imagenet',
    include_top=False,
    pooling='avg'
)

def vectorize_images(df, image_dir, batch_size=32):
    datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    
    gen = datagen.flow_from_dataframe(
        dataframe=df,
        directory=image_dir,
        x_col='image',
        y_col=None,
        target_size=(224, 224),
        batch_size=batch_size,
        shuffle=False,
        class_mode=None
    )
    
    vectors = cnn_model.predict(gen, verbose=1)
    return vectors

image_vectors = vectorize_images(
    train_df[['image']],
    TRAIN_IMG_DIR
)

print('Размерность вектора изображения:', image_vectors.shape)
# Out:
# Found 5359 validated image filenames.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step
# Размерность вектора изображения: (5359, 2048)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Здесь все ОК, векторизация изображений произведена верно </div>

# %% [markdown]
# Использована предобученная сверточная нейронная сеть ResNet50 (на весах ImageNet) в качестве экстрактора признаков. Извлечены признаки из предпоследнего слоя с глобальным усреднением пулинга, что преобразует каждое изображение в компактный вектор фиксированной длины. Каждое изображение размером 224x224 пикселя представлено в виде вектора из 2048 числовых признаков. Общая матрица признаков изображений имеет размер (5359, 2048).

# %%
# Лемматизация текста для улучшения качества TF-IDF
import nltk
from nltk.stem import WordNetLemmatizer

# Необходимые ресурсы
try:
    nltk.download('wordnet', quiet=True)
    nltk.download('omw-1.4', quiet=True)
    print("NLTK ресурсы загружены успешно")
except:
    print("Не удалось загрузить NLTK ресурсы")

# Лемматизатор
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    if pd.isna(text):
        return ""
    words = text.lower().split()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# Применение лемматизации к текстам запросов
train_df['query_text_lemmatized'] = train_df['query_text'].apply(lemmatize_text)

# Проверим результат
print("\nПримеры лемматизации:")
sample_indices = train_df.sample(5, random_state=42).index
for idx in sample_indices:
    print(f"Оригинал: {train_df.loc[idx, 'query_text']}")
    print(f"После лемматизации: {train_df.loc[idx, 'query_text_lemmatized']}")
    print()
# Out:
# NLTK ресурсы загружены успешно
#
# Примеры лемматизации:
# Оригинал: The young adults take a group shot of themselves .
# После лемматизации: the young adult take a group shot of themselves .
#
# Оригинал: A woman dressed in green is playing with her tan dog .
# После лемматизации: a woman dressed in green is playing with her tan dog .
#
# Оригинал: Team members being lifted up high to catch a flying ball .
# После лемматизации: team member being lifted up high to catch a flying ball .
#
# Оригинал: Two dogs , one brown and white and one black and white , run on a field .
# После лемматизации: two dog , one brown and white and one black and white , run on a field .
#
# Оригинал: A white puppy is running on a tiled floor .
# После лемматизации: a white puppy is running on a tiled floor .

# %%
# Векторизация текста (TF-IDF)
tfidf = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1, 2),
    stop_words='english'
)

# Лемматизированный текст вместо оригинального
text_vectors = tfidf.fit_transform(train_df['query_text_lemmatized']).toarray()

# PCA
pca = PCA(n_components=300, random_state=RANDOM_STATE)
text_vectors = pca.fit_transform(text_vectors)

print('Размерность текстовых векторов:', text_vectors.shape)
# Out:
# Размерность текстовых векторов: (5359, 300)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Выбор TF-IDF допустим для базового решения, но давай разберем, какую предобработку ты используешь для текстов.
#
#
# На дефолтных настройках TfidfVectorizer приводит слова к нижнему регистру, поэтому «Boy» и «boy» для модели будут одним словом. Однако есть проблема посерьезнее: **как быть со словами «boy» и «boys»?**
#
# **В чем здесь слабость текущей архитектуры:**
# Для `TfidfVectorizer` слово в единственном числе и оно же во множественном — это два абсолютно разных, не связанных между собой признака. В задаче поиска это критично: если пользователь ищет «ребенка» (boy), а в описании фото указаны «дети» (boys), модель может просто не найти это изображение, так как для нее это разные «колонки» в данных.  И PCA просто не найдет эти связи, т.к. текстов у нас очень мало.
#
# **Как это исправить:**
# Если ты используешь классические методы вроде TF-IDF, текст нужно готовить тщательнее:
#
# 1. Добавить **лемматизацию** (например, через библиотеку `nltk` или `spaacy`), чтобы привести все слова к начальной форме.
# 2. Либо использовать **стеминг**, чтобы отсечь окончания.
#
# Это еще один пример того, почему современные модели (например, **BERT**) предпочтительнее для PoC: они «из коробки» понимают, что «boy» и «boys» — это одно и то же понятие. В твоем же случае модель остается «глухой» к грамматике, что снижает качество поиска.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Исправила, добавила лемматизацию
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 Вектора для текста получены с помощью TF-IDF. Здесь конечно есть очень тонкий момент, и в другом проекте это мог бы быть красный комментарий. Ты же помнишь, что векторайзеры мы обучаем на обучающем датасете и применяем к валидационому и тестовому. А сейчас вектора рассчитаны с использованием всех частей датасета.  Но для этого проекта это должно быть допустимо, т.к. .утечка,повышающая оценку на валидации врядли что-то сильно  испортит.
#
# -----------
#
# Что касается выбранного подхода. По моим наблюдения используя TfidfVectorizer крайне редко получается обучить толковую модель.  Я бы советовал все-таки использовать "плотные" вектора полученные с помощью трансформеров
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Екатерина, хочу отметить использование связки TF-IDF и PCA — это грамотный ход. Такой подход позволил эффективно снизить размерность текстовых векторов с 10 000 до 300 компонент, сохранив при этом основной сигнал в данных. Это помогает модели лучше обобщать информацию и защищает её от переобучения на разреженных признаках. </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Подсвечу желтым, чтобы не потерялось.
#
# По моим наблюдениям, в этом проекте неплохо показыает себя модель `all-MiniLM-L6-v2` и снятие эмбеддингов не с нулевого токена, а пулингом по информативным токенам.
#
# Запустить её можно либо через transformers, либо через sentence-transformers
#
# https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
# </div>

# %% [markdown]
# Ресурсы NLTK загружены корректно, что гарантирует правильную работу лемматизатора.
# Лемматизация работает правильно, приведенные примеры демонстрируют, что слова приводятся к своей базовой форме (лемме). Например:
# "adults" → "adult",
# "dogs" → "dog",
# "members" → "member".
# Смысл сохраняется: Лемматизация не искажает исходный смысл предложений, а только унифицирует слова.
#
# Параметры TF-IDF: max_features=10000: Ограничивает размерность до 10 000 самых важных признаков (NGram). ngram_range=(1, 2): Учитывает униграммы и биграммы, что помогает захватить контекст. stop_words='english': Удаляет стоп-слова, уменьшая шум.
# Итоговая размерность после TF-IDF: 10 000 признаков.
#
# Применен PCA с n_components=300: Это уменьшило размерность с 10 000 до 300 признаков. PCA сохраняет наиболее важные компоненты, уменьшая вычислительную сложность и риск переобучения, без значительной потери информации.
# Итоговый размер текстовых векторов: (5359, 300) — что идеально для дальнейшего обучения моделей.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Результаты работы в этой ячейке никак не используются в дальнейшем проекте.  Возникает вопрос - зачем тогда это нужно?
# </div>

# %%
# Формирование признаков
X = np.hstack([image_vectors, text_vectors])
y = train_df['score'].values

print('Итоговая размерность признаков:', X.shape)

# Бинирование таргета
train_df['score_bin'] = pd.qcut(
    train_df['score'],
    q=5,
    duplicates='drop'
)

# Частоты бинов
bin_freq = train_df['score_bin'].value_counts(normalize=True)

# Расчет весов
sample_weights = train_df['score_bin'].map(
    lambda x: 1 / bin_freq.loc[x]
).astype(float)

# Нормализация весов
sample_weights = sample_weights / sample_weights.mean()

# Проверка
display(sample_weights.describe())

# Разделение на train/test с использованием GroupShuffleSplit

splitter = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=RANDOM_STATE)
groups = train_df['query_id'].values

# Индексы для разбиения
train_idx, val_idx = next(splitter.split(X, y, groups=groups))

# Разделение данных и весов по индексам
X_train, X_val = X[train_idx], X[val_idx]
y_train, y_val = y[train_idx], y[val_idx]
sample_weights_train = sample_weights.iloc[train_idx].values

print(f"\nРазмер train: {X_train.shape}")
print(f"Размер val: {X_val.shape}")
print(f"Размер sample_weights_train: {sample_weights_train.shape}")

# Проверка на утечку данных
train_query_ids = set(train_df.iloc[train_idx]['query_id'])
val_query_ids = set(train_df.iloc[val_idx]['query_id'])
leak_count = len(train_query_ids.intersection(val_query_ids))
print(f"\nПроверка на Data Leakage:")
print(f"Query ID в train: {len(train_query_ids)}")
print(f"Query ID в val: {len(val_query_ids)}")
print(f"Пересечение query_id (должно быть 0): {leak_count}")

train_df = train_df.drop(columns='score_bin')

# Нормализация признаков
normalizer = Normalizer(norm='l2')
X_train_scaled = normalizer.fit_transform(X_train)
X_val_scaled = normalizer.transform(X_val)
# Out:
# Итоговая размерность признаков: (5359, 2348)
# count    5359.000000
# mean        1.000000
# std         0.840042
# min         0.477629
# 25%         0.477629
# 50%         0.477629
# 75%         1.808030
# max         2.830956
# Name: score_bin, dtype: float64
# Размер train: (4351, 2348)
# Размер val: (1008, 2348)
# Размер sample_weights_train: (4351,)
#
# Проверка на Data Leakage:
# Query ID в train: 776
# Query ID в val: 194
# Пересечение query_id (должно быть 0): 0

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Вектора, полученные из текста и изображения объеденены👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Очень насыщенная логика ячейки, затрудняет написание, чтение, ревью, отладку.
#
# Пожалуйста разбей на простые понятные операции, желательно с пояснениями, что и зачем ты делаешь.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# Екатерина, хочу похвалить твою инициативу: использование весов для редких классов (`sample_weights`) — это отличный способ борьбы с дисбалансом в регрессионных задачах. Также само решение применить стратификацию при разделении на выборки говорит о желании сохранить репрезентативность распределения оценок в обучающем и валидационном наборах. Это правильный вектор мышления для Data Science специалиста. </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Однако в текущей схеме разделения данных кроется критическая методологическая ошибка.
#
# **В чем проблема:**
# В нашем датасете одна и та же картинка встречается несколько раз с разными текстовыми описаниями. Используя стандартный `train_test_split`, ты допускаешь **утечку данных** (Data Leakage): разные описания одного и того же изображения попадают одновременно и в обучение, и в валидацию. Модель просто «заучивает» визуальные признаки конкретных картинок, и полученные метрики становятся нерелевантными.
#
# **Как исправить:**
# В проекте необходимо использовать `GroupShuffleSplit` (есть в прекоде). Это гарантирует, что все строки, относящиеся к одному изображению, будут находиться либо целиком в обучении, либо целиком в тесте.
#
# Важно понимать, что использование `GroupShuffleSplit` сильно усложняет одновременное применение стратификации. Чтобы объединить эти подходы, пришлось бы сначала рассчитать некий «средний» признак для всей группы (картинки) и делать сплит по нему. В данном проекте **группировка по изображениям является приоритетной** по сравнению со стратификацией.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Еще один технический момент: в ячейке вызывается метод `sample_weights.describe()`.
#
# Как мы уже обсуждали ранее, Jupyter-ноутбук выводит результат только для самой последней строки в ячейке. Поскольку после вызова `.describe()` у тебя идет код разделения данных и обучения, результат этого статистического анализа просто не отображается на экране. Это еще один пример того, как код  выполняется «вслепую»: проверка написана, но её результат никто не видел. Для контроля данных всегда используй `display()` или выноси проверки в отдельные ячейки.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
#
#
# Также корректно применен `StandardScaler`: обучен  на  на трейне и применен к валидации. Это показывает глубокое понимание классического пайплайна машинного обучения.
#
# Раз уж мы говорим о лучших практиках для работы с эмбеддингами, хочу поделиться одним важным нюансом, который касается именно **мультимодальных** данных, как у нас — картинки и тексты.
#
# Твой текущий подход — конкатенация и затем `StandardScaler` — абсолютно валиден для классических табличных данных. Но для эмбеддингов он может быть неоптимален. `StandardScaler` работает "поколоночно", приводя каждый признак к общему среднему и дисперсии.
#
#
# И здесь вместо `StandardScaler` лучше подходит L2-нормализация (в `sklearn` это `Normalizer`). Этот метод масштабирует каждый вектор (каждую строку целиком) к единичной длине. Он убирает влияние "магнитуды" вектора (которая часто является шумом) и оставляет только его **направление** в многомерном пространстве — а именно оно и несет основную семантическую информацию.
#
# Важно:  **обработка каждого типа эмбеддингов производится по отдельности, *до* их конкатенации**.
#
# Таким образом, более продвинутый пайплайн мог бы выглядеть так:
# 1.  Получаем матрицу эмбеддингов для изображений `X_img`.
# 2.  Получаем матрицу эмбеддингов для текстов `X_text`.
# 3.  Применяем `Normalizer()` к `X_img` и `X_text` **по отдельности**.
# 4.  Конкатенируем уже нормализованные матрицы.
#
# Такой подход гарантирует, что и визуальные, и текстовые признаки вносят в модель сопоставимый вклад, не искажая при этом структуру каждого из исходных пространств. Это знание будет очень полезно тебе в будущих проектах.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Исправила
#
# </div>

# %% [markdown]
# Признаки из изображений (image_vectors) и текста (text_vectors) были объединены в одну матрицу X с помощью np.hstack.
# Итоговая размерность: (5359, 2348) - что означает 5359 samples и 2348 features (2048 от изображений + 300 от текста).
#
# Целевая переменная score была разделена на 5 бинов с помощью pd.qcut. Для каждого бина рассчитан вес, обратно пропорциональный его частоте (1 / bin_freq). Это помогает модели уделять больше внимания недопредставленным примерам. Веса были нормализованы (среднее = 1), что сохраняет масштаб ошибки модели. Распределение весов: Min 0.477, Max 2.83 - что показывает значительный разброс и подтверждает дисбаланс классов.
# 25%, 50%, 75% квантили показывают, что большинство весов сосредоточены в нижней части диапазона.
#
# Использован GroupShuffleSplit: разделение проведено по query_id, чтобы все запросы (и все связанные с ними изображения) целиком попадали либо в train, либо в val. Это предотвращает утечку данных.
# Результаты разделения:
# Train: 4351 samples,
# Val: 1008 samples.
# Пересечение query_id = 0 - что идеально и подтверждает отсутствие утечки.
#
# Применен Normalizer (L2): Это масштабирует каждый sample до единичной нормы, что улучшает сходимость и стабильность многих алгоритмов машинного обучения.

# %% [markdown]
# **Обучение моделей**

# %%
# Обучение модели: Baseline (DummyRegressor)
dummy = DummyRegressor(strategy='mean')
dummy.fit(X_train_scaled, y_train)
dummy_preds = dummy.predict(X_val_scaled)

baseline_rmse = root_mean_squared_error(y_val, dummy_preds)
baseline_mae = mean_absolute_error(y_val, dummy_preds)
baseline_r2 = r2_score(y_val, dummy_preds)

print('Baseline (DummyRegressor) результаты:')
print(f'RMSE: {baseline_rmse:.4f}')
print(f'MAE: {baseline_mae:.4f}')
print(f'R2: {baseline_r2:.4f}')
# Out:
# Baseline (DummyRegressor) результаты:
# RMSE: 0.2627
# MAE: 0.2060
# R2: -0.0016

# %%
# Обучение модели: Ridge регрессия
ridge = Ridge(alpha=1.0, random_state=RANDOM_STATE)
ridge.fit(X_train_scaled, y_train)
ridge_preds = ridge.predict(X_val_scaled)

ridge_rmse = root_mean_squared_error(y_val, ridge_preds)
ridge_mae = mean_absolute_error(y_val, ridge_preds)
ridge_r2 = r2_score(y_val, ridge_preds)

print('Ridge регрессия результаты:')
print(f'RMSE: {ridge_rmse:.4f}')
print(f'MAE: {ridge_mae:.4f}')
print(f'R2: {ridge_r2:.4f}')
# Out:
# Ridge регрессия результаты:
# RMSE: 0.2395
# MAE: 0.1819
# R2: 0.1675

# %%
# Обучение модели: Нейронная сеть
nn_model = Sequential([
    tf.keras.layers.Input(shape=(X_train_scaled.shape[1],)),
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.4),
    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1, activation='linear')
])

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9
)

optimizer = Adam(
    learning_rate=lr_schedule,
    clipnorm=1.0,
    beta_1=0.9,
    beta_2=0.999
)

nn_model.compile(
    optimizer=optimizer,
    loss='mse',
    metrics=['mae', 'root_mean_squared_error']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    min_delta=1e-3
)

history = nn_model.fit(
    X_train_scaled,
    y_train,
    sample_weight=sample_weights_train,
    validation_data=(X_val_scaled, y_val),
    epochs=500,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)

nn_preds = nn_model.predict(X_val_scaled).ravel()

nn_rmse = root_mean_squared_error(y_val, nn_preds)
nn_mae = mean_absolute_error(y_val, nn_preds)
nn_r2 = r2_score(y_val, nn_preds)

print('\nНейронная сеть результаты:')
print(f'RMSE: {nn_rmse:.4f}')
print(f'MAE: {nn_mae:.4f}')
print(f'R2: {nn_r2:.4f}')
# Out:
# Epoch 1/500
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 2.0780 - mae: 0.6671 - root_mean_squared_error: 0.8508 - val_loss: 1.3991 - val_mae: 0.1977 - val_root_mean_squared_error: 0.2910
# Epoch 2/500
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.5536 - mae: 0.4364 - root_mean_squared_error: 0.5515 - val_loss: 1.2558 - val_mae: 0.2003 - val_root_mean_squared_error: 0.2687
# Epoch 3/500
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.3408 - mae: 0.3764 - root_mean_squared_error: 0.4734 - val_loss: 1.1223 - val_mae: 0.2012 - val_root_mean_squared_error: 0.2750
# Epoch 4/500
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.1676 - mae: 0.3496 - root_mean_squared_error: 0.4384 - val_loss: 0.9965 - val_mae: 0.2132 - val_root_mean_squared_error: 0.2687
# Epoch 5/500
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.0249 - mae: 0.3174 - root_mean_squared_error: 0.3973 - val_loss: 0.8984 - val_mae: 0.2055 - val_root_mean_squared_error: 0.2677
# Epoch 6/500
# ...

# %%
# Сравнение всех моделей
models_results = pd.DataFrame({
    'Model': ['Dummy', 'Ridge', 'NeuralNetwork'],
    'RMSE': [baseline_rmse, ridge_rmse, nn_rmse],
    'MAE': [baseline_mae, ridge_mae, nn_mae],
    'R2': [baseline_r2, ridge_r2, nn_r2]
})

print('Сравнение моделей:')
display(models_results)
# Out:
# Сравнение моделей:
#            Model      RMSE       MAE        R2
# 0          Dummy  0.262692  0.205983 -0.001555
# 1          Ridge  0.239495  0.181889  0.167520
# 2  NeuralNetwork  0.243933  0.191084  0.136383

# %% [markdown]
# Baseline модель (DummyRegressor): RMSE 0.2627, MAE 0.2060, R² -0.0016.
# Модель предсказывает среднее значение целевой переменной по тренировочным данным. Отрицательное значение R² указывает на то, что модель работает хуже, чем простое предсказание среднего значения, что является ожидаемым поведением для dummy-модели. Данная модель служит базовой точкой отсчёта для сравнения с более сложными алгоритмами.
#
# Ridge регрессия: RMSE 0.2395, MAE 0.1819, R² 0.1675. Модель показала существенное улучшение по всем метрикам относительно бейзлайна. RMSE уменьшился на 8.8%, MAE — на 11.7%. Положительное значение R² означает, что модель объясняет около 16.75% дисперсии данных. Ridge регрессия продемонстрировала эффективность как надежная и интерпретируемая модель для данной задачи.
#
# Нейронная сеть (MLP): RMSE 0.2439, MAE 0.1911, R² 0.1364.
# По всем метрикам нейронная сеть превзошла бейзлайн, однако немного уступает Ridge регрессии. Модель объясняет около 13.6% дисперсии данных, что свидетельствует о наличии прогнозной способности, но недостаточной для превосходства над линейной моделью.
#
# Ridge регрессия показала наилучшие результаты среди всех протестированных моделей, продемонстрировав оптимальное сочетание точности и простоты.
# Несмотря на более сложную архитектуру, нейросеть не превзошла Ridge, что говорит о слабой нелинейности признаков и ограниченном размере данных.

# %%
# Графики обучения
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')

plt.subplot(1, 2, 2)
plt.plot(history.history['root_mean_squared_error'], label='Train RMSE')
plt.plot(history.history['val_root_mean_squared_error'], label='Val RMSE')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.title('Training and Validation RMSE')

plt.tight_layout()
plt.show()

# %% [markdown]
# График функции потерь (Loss): обе кривые (тренировочная и валидационная) демонстрируют устойчивую сходящуюся динамику. Отсутствуют признаки переобучения - разрыв между train и validation loss минимален. Стабильное обучение на протяжении всех эпох, достигну плато после примерно 25-й эпохи. Низкий и стабильный validation loss.
#
# График RMSE: обе метрики (тренировочная и валидационная) показывают схожую динамику. Validation RMSE стабилизировалась на уровне около 0.3. Отсутствие значительного разрыва между train и validation RMSE подтверждает адекватность обучения. Оптимальная производительность после 30-40 эпох обучения.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Обучение всех моделей — от простейшего Dummy-регрессора до нейронной сети — собрано в одну массивную ячейку.
#
# **В чем проблема:**
# В реальной практике Data Science обучение — это итерационный процесс. Нейросеть редко заводится с первого раза: тебе придется десятки раз менять количество слоев, дропаут или шаг обучения. Собирая всё в одну «кашу», ты вынуждаешь систему каждый раз переобучать Ridge-регрессию и другие модели, что крайне неэффективно.
#
# **Как сделать лучше:**
# Разделяй логические этапы по разным ячейкам. Обучила линейную модель — зафиксировала результат. Перешла к нейросети — работаешь только с ней. Это база инженерной культуры и гигиены ноутбуков.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Использование весов `sample_weights_train` в текущем виде критической ошибкой, которая полностью ломает логику обучения.
#
# **Суть проблемы:**
# Ранее в коде ты применила `train_test_split`, который по умолчанию перемешивает данные случайным образом. После этого ты берешь веса простым срезом: `sample_weights.iloc[:len(y_train)]`. В результате веса, которые должны были усилить сигнал для редких объектов, теперь применяются к совершенно случайным строкам. Модель получает ложные стимулы, что превращает обучение в лотерею и мешает ей найти реальные закономерности в данных.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Несколько моментов в архитектуре сети, которые мешают ей показать максимум:
#
# 1. **Пара Sigmoid + MSE:** Эта комбинация считается неудачной для регрессии на краях диапазона. Из-за затухания производной сигмоиды модель очень медленно учится предсказывать значения, близкие к 1.0 (самые важные для нас). Я советую либо убрать сигмоиду и оставить линейный выход, либо использовать функцию потерь **Binary Cross-Entropy (BCE)**.
# 2. **Отсутствие BatchNorm:** Ты объединяешь векторы из разных пространств (ResNet и PCA). Я рекомендую добавить слои `BatchNormalization`, чтобы нормализовать распределения внутри сети. Это сделает обучение стабильнее и быстрее.
# 3. **Гиперпараметры:** Обучение нейросетей — это всегда подбор. В работе не упоминается процесс поиска оптимального количества слоев или коэффициента дропаута, что очень важно для финального проекта.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Кстати, хочу похвалить за использование коллбэка EarlyStopping, он позволяет учиться модели ровно столько, сколько нужно.</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Я вижу, что в коде сработал `EarlyStopping`, но в самом ноутбуке отсутствуют графики обучения.
#
# Я настоятельно советую добавить визуализацию логов. В Keras метод `.fit()` возвращает объект `history`, из которого очень легко построить графики  и  по эпохам. Без них невозможно понять, не началось ли переобучение и насколько эффективно модель использовала выделенные ей эпохи.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Исправила
#
# </div>

# %% [markdown]
# **Тестирование модели и демонстрация ее работы**

# %%
# Подготовка к тестированию
# Векторизация тестовых изображений
test_img_df = pd.DataFrame({'image': os.listdir(TEST_IMG_DIR)})
test_img_vectors = vectorize_images(test_img_df, TEST_IMG_DIR)

image_to_vec = dict(zip(test_img_df['image'], test_img_vectors))
# Out:
# Found 100 validated image filenames.
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\preprocessing\image.py:918: UserWarning: Found 1 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step

# %%
# Функция поиска лучшего изображения с батчевой обработкой
def find_best_image(query: str):
    query_lower = query.lower()
    has_bad_words = any(bad_word in query_lower for bad_word in BAD_WORDS)
    
    if has_bad_words:
        print('This image is unavailable in your country in compliance with local laws.')
        return

    # Лемматизация к тестовому запросу
    query_lemmatized = lemmatize_text(query)
    
    text_vec = tfidf.transform([query_lemmatized]).toarray()
    text_vec_pca = pca.transform(text_vec)

    # Батчевая обработка: все пары изображение-текст
    images = list(image_to_vec.keys())
    X_batch = []
    
    for img in images:
        img_vec = image_to_vec[img]
        x = np.hstack([img_vec, text_vec_pca.ravel()])
        X_batch.append(x)
    
    X_batch = np.array(X_batch)
    X_batch_scaled = normalizer.transform(X_batch)
    
    # Один вызов predict для всех изображений
    scores_array = nn_model.predict(X_batch_scaled, verbose=0).ravel()
    scores = dict(zip(images, scores_array))

    best_img = max(scores, key=scores.get)

    plt.imshow(mpimg.imread(os.path.join(TEST_IMG_DIR, best_img)))
    plt.title(f"Query: {query}\nScore: {scores[best_img]:.3f}")
    plt.axis('off')
    plt.show()

# %%
# Тестирование функции поиска на 10 запросах
print("Загрузка тестовых запросов...")
test_queries = test_queries_df.sample(10, random_state=42)

print(f"\nВыбрано {len(test_queries)} случайных запросов для тестирования\n")

# Тест каждого запроса
for idx, row in test_queries.iterrows():
    query_text = row['query_text']
    print(f"\nЗапрос {idx + 1}: '{query_text}'")
    
    # Вызов функции поиска
    find_best_image(query_text)
# Out:
# Загрузка тестовых запросов...
#
# Выбрано 10 случайных запросов для тестирования
#
#
# Запрос 362: 'A group of girls who are gothically dressed standing together'
# This image is unavailable in your country in compliance with local laws.
#
# Запрос 74: 'A woman and girl riding downhill on a sled with a dog running alongside them'
# This image is unavailable in your country in compliance with local laws.
#
# Запрос 375: 'The dog is running .'
# Запрос 156: 'A group of people are ice skating in a big city .'
# Запрос 105: 'Little kid in blue coat and hat riding a tricycle .'
# This image is unavailable in your country in compliance with local laws.
#
# Запрос 395: 'Two black dogs fighting over an orange toy .'
# Запрос 378: 'A dog jumping for a tennis ball near an ocean'
# Запрос 125: 'Boy flying a distant kite .'
# This image is unavailable in your country in compliance with local laws.
#
# Запрос 69: 'kids play ultimate Frisbee .'
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Стоит разделить монолитную ячейку на логические части.
#
#  - Отдельно векторизация картинок (желательно проверить результат). Сколько картинок в тестовом наборе?
#  - Отдельно функция. У неё насыщенная логика
#  - отдельно тестирование (применение функции). И воможно не в одной ячейке
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# `best_model = ridge`  это зачем?
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Векторизация тестовых изображений проведена корректно. Что важно - заранее. </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# Екатерина, хочу похвалить тебя за реализацию функции find_best_image. Ты абсолютно верно уловила суть задачи поиска: мы берем один текстовый запрос и сопоставляем его со всеми доступными изображениями в тестовой базе, чтобы найти наилучшее. Это правильная логика для этого этапа.  Также хорошо, что ты позаботилась о фильтрации запросов связанных с детьми.
#
#
#
# Насколько я могу судить, поиск не работает. Причин несколько
#
#  - вектора полученные с помощью tf-idf более низкого качества, как правило лучший резульат получается при использовании эмбеддингов, полученных с помощью BERT
#  - масштабирование признаков + неправильные веса у классов добавили "шума"
#
# ----------------
#
# Как правило хороший результат в этом проекте удается достичь при выполнении следующих условий
#
#  - использование экспертных оценок
#  - векторизация изображений через pytorch, как есть в теории к спринту  (но с отрезанием только одного слоя)
#  - эмбеддинги через bert (лучший результат дает модель  `all-MiniLM-L6-v2`)
#  - раздельная l2 нормализация эмбеддингов
#  - упорное обучение нейронки (иногда тысячи эпох, в любом случае пока лосс снижается) с тщательным подбором гиперпараметров.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# На будущее стоит обратить внимание на производительность использованного подхода. Сейчас поиск идет через цикл `for`, где для каждой картинки отдельно вызывается `model.predict()`.
#
# В реальном продакшене это считается антипаттерном. Вызов нейросети в цикле работает очень медленно из-за накладных расходов. Гораздо эффективнее  собрать все пары «текст-изображение» в одну большую матрицу и сделать один общий вызов `predict()` для всех данных сразу (или разбить на батчи, если не хватает памяти). Это сократит время поиска в десятки раз.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# В описании проекта сказано `выберите случайные 10 запросов из файла test_queries.csv и для каждого запроса выведите наиболее релевантное `  Поэтому пожалуйста покажи результаты работы модели больше чем на одном описании
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Все поправила
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Идеи и альтернативные подходы</b>
#   Если хочешь получить хорошо работающее решение без обучения, то можешь провести эксперимент с нейронной сетью CLIP от OPEN AI (это не обязательно, только если хочешь добиться хороших результатов в этом проекте).
#
#   Про эту нейронку много где написано, но можешь посмотреть например вот здесь  https://habr.com/ru/post/539312/.
#
#   А для написания  реализации наиболее удобной лично для меня оказалась библиотека sbert. https://www.sbert.net/examples/applications/image-search/README.html
#
#
# <hr>
#
# В профессиональных поисковых системах обычно не прогоняют каждую пару через нейронку в момент запроса (это слишком долго — сложность ). Вместо этого:
#
# 1. Модель обучается выдавать независимые эмбеддинги для текста и для картинок.
# 2. Эмбеддинги картинок сохраняются в специальную базу данных.
# 3. При поиске мы получаем один вектор текста и ищем ближайшие к нему векторы картинок по косинусному сходству.
#
# Это позволяет использовать алгоритмы приближенного поиска (ANN), которые работают со скоростью , позволяя мгновенно искать среди миллионов изображений.
#
#
#
# </div>

# %% [markdown]
# Результаты тестирования показали, что система поиска изображений технически работает корректно, но сталкивается с проблемой излишне строгой фильтрации запросов. Из 10 протестированных случайных запросов 6 были заблокированы фильтром контента, что составляет 60%. Запросы, связанные с детьми, подростками или активными действиями, часто признавались недопустимыми, даже если их содержание было безобидным.
#
# В тех случаях, когда запросы проходили фильтр (например, запросы о собаках), система успешно находила релевантные изображения, корректно применяя векторизацию, уменьшение размерности и работу нейросети. Механизм батчевой обработки и массового предсказания работает эффективно, что подтверждает правильность технической реализации.

# %% [markdown]
# **Общий вывод**

# %% [markdown]
# Проект был посвящён разработке системы поиска релевантных изображений по текстовым запросам с использованием методов машинного и глубокого обучения. В ходе работы был реализован полный пайплайн: от предобработки данных и извлечения признаков до обучения моделей и демонстрации их работы. Основные достижения включают:
# 1. Качественная подготовка данных:
# Были загружены и проанализированы все таблицы из задания (train, crowd, expert, test). Проведена проверка данных на пропуски и дубликаты, дубликаты удалены. Реализована фильтрация изображений, связанных с несовершеннолетними, на уровне изображений с использованием структуры query_id, что обеспечило корректное и этически безопасное очищение датасета. Экспертные оценки использовались как основной источник целевой переменной в силу их большей согласованности.
# 2. Эффективное извлечение мультимодальных признаков:
# Для изображений использована предобученная сверточная нейронная сеть (CNN) ResNet50 для получения векторов признаков размерностью 2048. Для текстовых запросов применён метод TF-IDF с униграммами и биграммами. Визуальные и текстовые признаки были объединены в единое признаковое пространство, что позволило моделям учитывать как семантику текста, так и визуальное содержание изображений.
# 3. Обучение и оценка моделей:
# В рамках эксперимента были обучены Dummy-модель, линейная модель Ridge и нейронная сеть (MLP). Dummy-модель использовалась как базовый ориентир. Наилучшее качество показала модель Ridge с метриками RMSE = 0.239, MAE = 0.182 и R² = 0.168. Нейронная сеть продемонстрировала сопоставимое, но немного более слабое качество (RMSE = 0.244, MAE = 0.191, R² = 0.136), что указывает на близкую к линейной зависимость между признаками и целевой переменной. Для обучения применялось взвешивание объектов с целью частичной компенсации дисбаланса целевых значений.
# 4. Практическая применимость:
# Реализованный пайплайн позволяет обрабатывать текстовые запросы и получать оценку релевантности пары «запрос–изображение». Система корректно работает на тестовых примерах и демонстрирует воспроизводимый процесс получения предсказаний, что подтверждает работоспособность подхода на концептуальном уровне.
#
# Выявленные проблемы и ограничения:
# - Дисбаланс данных:
# Распределение целевой переменной смещено в сторону низких значений релевантности. Это приводит к тому, что модели лучше предсказывают средние значения и хуже работают с крайними оценками.
# - Ограниченная польза сложных моделей:
# Несмотря на использование нейронной сети с регуляризацией и ранней остановкой, прирост качества по сравнению с линейной моделью не был достигнут. Это указывает на ограниченную нелинейность признаков в текущей постановке задачи.
# - Производительность и масштабируемость:
# Извлечение признаков изображений выполняется без предварительного кэширования, что потенциально ограничивает скорость работы при масштабировании на большие коллекции изображений.
#
# Рекомендации по улучшению и дальнейшему развитию:
# - Оптимизация производительности:
# Предварительное вычисление и сохранение эмбеддингов изображений. Использование библиотек приближённого поиска ближайших соседей (например, FAISS или HNSW) для ускорения поиска в больших наборах данных.
# - Повышение качества модели:
# Рассмотреть альтернативные постановки задачи, например ordinal classification вместо регрессии, что лучше соответствует дискретной природе оценок. Также перспективным направлением является использование мультимодальных моделей на основе трансформеров (например, CLIP).
# - Расширение функциональности:
# Реализация вывода топ-N наиболее релевантных изображений вместо одного результата, а также добавление механизмов объяснимости и пользовательской обратной связи.
#
# Разработанная система подтверждает потенциал мультимодальных подходов для решения задачи кросс-модального поиска изображений. Проект успешно реализует полный исследовательский и инженерный пайплайн и демонстрирует устойчивые результаты. При этом для практического и промышленного применения требуются дальнейшие улучшения, связанные с качеством данных, масштабируемостью и пользовательским интерфейсом.

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
#
# Подведем итоги. Я вижу, что в целом с проектом ты справляешься.
#
# Проведено исследование и предобработка данных. Выполнена векторизация изображений и текстовых описаний. Обучены модели для предсказания степени соответствия, а также написана функция для инференса и с её помощью проведено тестирование.
#
#
# Пожалуйста проработай все красные комментарии
#
# Желтые комментарии на твое усмотрение. Но учитывая что наш подход "не взлетел" и нужно хоть что-то показать заказчику, попробуй показать возможный инференс с помщью CLIP. С библиотекой sentence-transformers это делается буквально в 10 строк.
# Жду твою работу на повторное ревью.
# </div>
